# %%
pip install pywhatkit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pywhatkit
#   Downloading pywhatkit-5.4-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from pywhatkit) (10.3.0)
# Collecting pyautogui (from pywhatkit)
#   Downloading PyAutoGUI-0.9.54.tar.gz (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.2 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.2 kB 217.9 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.2 kB 326.8 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 408.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from pywhatkit) (2.31.0)
# Collecting wikipedia (from pywhatkit)
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting Flask (from pywhatkit)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from Flask->pywhatkit) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from Flask->pywhatkit) (3.1.3)
# Collecting itsdangerous>=2.1.2 (from Flask->pywhatkit)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from Flask->pywhatkit)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting blinker>=1.6.2 (from Flask->pywhatkit)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting pymsgbox (from pyautogui->pywhatkit)
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pytweening>=1.0.4 (from pyautogui->pywhatkit)
#   Downloading pytweening-1.2.0.tar.gz (171 kB)
#      ---------------------------------------- 0.0/171.2 kB ? eta -:--:--
#      ---------------- ---------------------- 71.7/171.2 kB 3.8 MB/s eta 0:00:01
#      ------------------------------------ - 163.8/171.2 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 171.2/171.2 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyscreeze>=0.1.21 (from pyautogui->pywhatkit)
#   Downloading PyScreeze-0.1.30.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pygetwindow>=0.0.5 (from pyautogui->pywhatkit)
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting mouseinfo (from pyautogui->pywhatkit)
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from requests->pywhatkit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from requests->pywhatkit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from requests->pywhatkit) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from requests->pywhatkit) (2024.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from wikipedia->pywhatkit) (4.12.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from click>=8.1.3->Flask->pywhatkit) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from Jinja2>=3.1.2->Flask->pywhatkit) (2.1.3)
# Collecting pyrect (from pygetwindow>=0.0.5->pyautogui->pywhatkit)
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\envs\tfm\lib\site-packages (from beautifulsoup4->wikipedia->pywhatkit) (2.5)
# Collecting pyperclip (from mouseinfo->pyautogui->pywhatkit)
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Downloading pywhatkit-5.4-py3-none-any.whl (15 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/101.7 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/101.7 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/101.7 kB ? eta -:--:--
#    --------------- ----------------------- 41.0/101.7 kB 245.8 kB/s eta 0:00:01
#    ----------------------------------- --- 92.2/101.7 kB 435.7 kB/s eta 0:00:01
#    -------------------------------------- 101.7/101.7 kB 450.7 kB/s eta 0:00:00
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ------------------------------------- -- 92.2/97.9 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 97.9/97.9 kB 1.9 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Building wheels for collected packages: pyautogui, wikipedia, pygetwindow, pyscreeze, pytweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for pyautogui (pyproject.toml): started
#   Building wheel for pyautogui (pyproject.toml): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.54-py3-none-any.whl size=37596 sha256=8cdc31480748b50215d62d7105d0ed2cd0cd4a1a3e3cffa2a007a28c2c596ebf
#   Stored in directory: c:\users\jefe.sistemas\appdata\local\pip\cache\wheels\95\dc\b1\fe122b791e0db8bf439a0e6e1d2628e48f10bf430cae13521b
#   Building wheel for wikipedia (setup.py): started
#   Building wheel for wikipedia (setup.py): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11706 sha256=017a04c08535c44c77fa60f3e9586f481dbc18240cdbfcde4d9a974db8dbd114
#   Stored in directory: c:\users\jefe.sistemas\appdata\local\pip\cache\wheels\8f\ab\cb\45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11080 sha256=085dba8f506fb613d5e8647d1262f6c9be9ffc81ba34eda4a1c011bcc1e745e3
#   Stored in directory: c:\users\jefe.sistemas\appdata\local\pip\cache\wheels\07\75\0b\7ca0b598eb4c21d43ba4bcc78a0538dfcf803a5997da33bc19
#   Building wheel for pyscreeze (pyproject.toml): started
#   Building wheel for pyscreeze (pyproject.toml): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.30-py3-none-any.whl size=14401 sha256=6766d3a674e3fc45a603a27a8e277f21ee88e2bbf0ca4646e8eab20d5e4eb650
#   Stored in directory: c:\users\jefe.sistemas\appdata\local\pip\cache\wheels\df\bc\15\d685ca085ca4b11e46e54cc3da4e501a98856c7fea8f604500
#   Building wheel for pytweening (setup.py): started
#   Building wheel for pytweening (setup.py): finished with status 'done'
#   Created wheel for pytweening: filename=pytweening-1.2.0-py3-none-any.whl size=8031 sha256=a04068b57371c6eba009e25575ee89c8c6e7af2e3f994101edaf0415da43421d
#   Stored in directory: c:\users\jefe.sistemas\appdata\local\pip\cache\wheels\db\81\dc\0d61a3c9614f288e057ab63924e2a49edbeed4ffc916dcda1e
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10903 sha256=e716d1f951cc3d834bd155c480235b823f36d338d2c8141e06357b32f7a65211
#   Stored in directory: c:\users\jefe.sistemas\appdata\local\pip\cache\wheels\20\0b\7f\939ac9ff785b09951c706150537572c00123412f260a6024f3
#   Building wheel for pymsgbox (pyproject.toml): started
#   Building wheel for pymsgbox (pyproject.toml): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7417 sha256=267215e94575f65cd5a411818def26b665dbf42c7e21b4c09adc39a9ed408b67
#   Stored in directory: c:\users\jefe.sistemas\appdata\local\pip\cache\wheels\85\92\63\e126ee5f33d8f2ed04f96e43ef5df7270a2f331848752e8662
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11136 sha256=3b881faf005e257ba4bbace4e609617a982453f4d7cf93aa6e9c109ac18d575a
#   Stored in directory: c:\users\jefe.sistemas\appdata\local\pip\cache\wheels\70\bd\ba\8ae5c080c895c9360fe6e153acda2dee82527374467eae061b
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11205 sha256=676ff94269cd384c6c9901bfab55a50b48cddea21b58705bd66b7be236af2843
#   Stored in directory: c:\users\jefe.sistemas\appdata\local\pip\cache\wheels\c4\e9\fc\b7a666dd4f9a3168fb44d643079b41d36ddab52f470707e820
# Successfully built pyautogui wikipedia pygetwindow pyscreeze pytweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: pytweening, pyrect, pyperclip, pymsgbox, pyscreeze, pygetwindow, mouseinfo, itsdangerous, click, blinker, wikipedia, pyautogui, Flask, pywhatkit
# Successfully installed Flask-3.0.3 blinker-1.8.2 click-8.1.7 itsdangerous-2.2.0 mouseinfo-0.1.3 pyautogui-0.9.54 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreeze-0.1.30 pytweening-1.2.0 pywhatkit-5.4 wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script flask.exe is installed in 'C:\Users\jefe.sistemas\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# pip install pywhatkit
import pywhatkit as kit

# Specify the phone number (with country code) and the message
phone_number = "+573057518324"
message = "Hello from Python! This is an instant WhatsApp message."

# Send the message instantly
kit.sendwhatmsg_instantly(phone_number, message)
